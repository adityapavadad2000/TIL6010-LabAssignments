# %% [markdown]
# # Submission
#
# Put the ipynb file and html file in the github branch you created in the last assignment and submit the link to the commit in brightspace

# %%
from plotly.offline import init_notebook_mode
import plotly.io as pio
import plotly.express as px

init_notebook_mode(connected=True)
pio.renderers.default = "plotly_mimetype+notebook"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#load data
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# ## Question 1:
#
# Recreate the barplot below that shows the population of different continents for the year 2007.
#
# *Hints:*
#
# - Extract the 2007 year data from the dataframe. You have to process the data accordingly
# - use [plotly bar](https://plotly.com/python-api-reference/generated/plotly.express.bar)
# - Add different colors for different continents
# - Sort the order of the continent for the visualisation. Use [axis layout setting](https://plotly.com/python/reference/layout/xaxis/)
# - Add text to each bar that represents the population

# %%
# YOUR CODE HERE

da = df.groupby("year").get_group(2007)
da

a = px.histogram(da , x = "pop" , y = 'continent' , color = 'continent' , orientation = 'h' )
a.update_yaxes( categoryorder= "total ascending")
a.update_traces(texttemplate = '%{x:2s}' , textposition = 'outside')
a.show()
# Out:
# <div>                            <div id="4a41ca2f-fc55-4f42-aa0c-f0a946183200" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a41ca2f-fc55-4f42-aa0c-f0a946183200")) {                    Plotly.newPlot(                        "4a41ca2f-fc55-4f42-aa0c-f0a946183200",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"continent=%{y}\u003cbr\u003esum of pop=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"x":[31889923,708573,150448339,14131858,1318683096,6980412,1110396331,223547000,69453570,27499638,6426679,127467972,6053193,23301725,49044790,2505559,3921278,248212
# ...

# %% [markdown]
# ## Question 2:
#
# Sort the order of the continent for the visualisation
#
# Hint: Use [axis layout setting](https://plotly.com/python/reference/layout/xaxis/)

# %%
# YOUR CODE HERE

da = df.groupby("year").get_group(2007)
da

a = px.histogram(da , x = "pop" , y = 'continent' , color = 'continent' , orientation = 'h' )
a.update_yaxes( categoryorder= "total descending")
a.update_traces(texttemplate = '%{x:2s}' , textposition = 'outside')
a.show()
# Out:
# <div>                            <div id="ecc049cc-f886-4485-868c-802f7760869f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecc049cc-f886-4485-868c-802f7760869f")) {                    Plotly.newPlot(                        "ecc049cc-f886-4485-868c-802f7760869f",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"continent=%{y}\u003cbr\u003esum of pop=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"x":[31889923,708573,150448339,14131858,1318683096,6980412,1110396331,223547000,69453570,27499638,6426679,127467972,6053193,23301725,49044790,2505559,3921278,248212
# ...

# %% [markdown]
# ## Question 3:
#
# Add text to each bar that represents the population

# %%
# YOUR CODE HERE

da = df.groupby("year").get_group(2007)
da

a = px.histogram(da , x = "pop" , y = 'continent' , color = 'continent' , orientation = 'h' )
a.update_yaxes( categoryorder= "total ascending")
a.update_traces(texttemplate = '%{x:2s}' , textposition = 'outside')
a.show()
# Out:
# <div>                            <div id="5c247303-8858-43d5-b67b-980472da7fad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c247303-8858-43d5-b67b-980472da7fad")) {                    Plotly.newPlot(                        "5c247303-8858-43d5-b67b-980472da7fad",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"continent=%{y}\u003cbr\u003esum of pop=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"x":[31889923,708573,150448339,14131858,1318683096,6980412,1110396331,223547000,69453570,27499638,6426679,127467972,6053193,23301725,49044790,2505559,3921278,248212
# ...

# %% [markdown]
# ## Question 4:
#
# Thus far we looked at data from one year (2007). Lets create an animation to see the population growth of the continents through the years

# %%
import plotly.express as px

fig = px.histogram(df, 
             x='continent', 
             y='pop',
             animation_frame='year',  
             title='Population Growth by Continent Over the Years',
             labels={'pop': 'Population'},
             category_orders={"continent": df.groupby("continent")["pop"].sum().sort_values(ascending=False).index},
             height=600,  
             color = 'continent'
            )

fig.update_layout(xaxis_title='Continent', yaxis_title='Population',  title_x=0.5, title_y=0.95)
# fig.update_xaxes(type='category')

fig.show()
# Out:
# <div>                            <div id="cb1c7c85-87ce-4390-9f9c-e160b0a7ff9d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb1c7c85-87ce-4390-9f9c-e160b0a7ff9d")) {                    Plotly.newPlot(                        "cb1c7c85-87ce-4390-9f9c-e160b0a7ff9d",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"continent=%{x}\u003cbr\u003eyear=1952\u003cbr\u003esum of Population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"x":["Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","As
# ...

# %%
# YOUR CODE HERE

df = px.data.gapminder()


b = px.histogram(df , x ='year' , y =  'continent' , color = "continent" )
b.update_yaxes( categoryorder = 'total ascending')
b.show()
# Out:
# <div>                            <div id="a6ebf204-76b8-4920-b536-04d9dcf6db97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6ebf204-76b8-4920-b536-04d9dcf6db97")) {                    Plotly.newPlot(                        "a6ebf204-76b8-4920-b536-04d9dcf6db97",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"continent=%{y}\u003cbr\u003esum of year=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007,1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007,1952,1957,1962,1967,1972,1977,1982,198
# ...

# %% [markdown]
# ## Question 5:
#
# Instead of the continents, lets look at individual countries. Create an animation that shows the population growth of the countries through the years

# %%
# YOUR CODE HERE
fig = px.bar(df, 
             x='pop', 
             y='country',
             animation_frame='year', 
             title='Population Growth by Continent',
             labels={'pop': 'Population'},
             category_orders={"country": df.groupby("country")["pop"].sum().sort_values(ascending=False).index},
             height=600, 
             color = 'continent'
            )


fig.update_layout(xaxis_title='Continent', yaxis_title='Population' , title_x=0.5, title_y=0.95)
# fig.update_xaxes(type='category')

fig.show()
# Out:
# <div>                            <div id="d42a11dc-3ba4-4a1b-92d8-ff801d7677bb" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42a11dc-3ba4-4a1b-92d8-ff801d7677bb")) {                    Plotly.newPlot(                        "d42a11dc-3ba4-4a1b-92d8-ff801d7677bb",                        [{"alignmentgroup":"True","hovertemplate":"continent=Asia\u003cbr\u003eyear=1952\u003cbr\u003ePopulation=%{x}\u003cbr\u003ecountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"textposition":"auto","x":[8425333,120447,46886859,4693836,556263527,2125900,372000000,82052000,17272000,5441766,1620914,86459025,607914,8865488,20
# ...

# %% [markdown]
# ## Question 6:
#
# Clean up the country animation. Set the height size of the figure to 1000 to have a better view of the animation

# %%
# YOUR CODE HERE

fig = px.bar(df, 
             x='pop', 
             y='country',
             animation_frame='year', 
             title='Population Growth by Continent',
#              labels={'pop': 'Population'},
             category_orders={"country": df.groupby("country")["pop"].sum().sort_values(ascending=False).index},
             height=1000, 
             color = 'continent'
            )
fig.update_layout(xaxis_title='Continent', yaxis_title='Population',title_x=0.5, title_y=0.95)
# fig.update_xaxes(type='category')


fig.show()
# Out:
# <div>                            <div id="18f062a0-23c9-4356-b052-609d0e5e61c3" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18f062a0-23c9-4356-b052-609d0e5e61c3")) {                    Plotly.newPlot(                        "18f062a0-23c9-4356-b052-609d0e5e61c3",                        [{"alignmentgroup":"True","hovertemplate":"continent=Asia\u003cbr\u003eyear=1952\u003cbr\u003epop=%{x}\u003cbr\u003ecountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"h","showlegend":true,"textposition":"auto","x":[8425333,120447,46886859,4693836,556263527,2125900,372000000,82052000,17272000,5441766,1620914,86459025,607914,8865488,20947571
# ...

# %% [markdown]
# ## Question 7:
#
# Show only the top 10 countries in the animation
#
# Hint: Use the axis limit to set this.

# %%
top_10 = df.groupby('year').apply(lambda x: x.nlargest(10, 'pop')).reset_index(drop=True)


fig = px.bar(top_10, 
             x='country', 
             y='pop',
             animation_frame='year',
             title='Top 10 Countries by Population Over the Years',
             height=600,
             color = "country"
            )


fig.update_layout(xaxis_title='Country', yaxis_title='Population' ,title_x=0.5, title_y=0.95)
fig.update_xaxes(type='category')
fig.update_xaxes( categoryorder = 'total descending')

fig.show()
# Out:
# <div>                            <div id="de6783a6-5be1-4a40-9146-cb160bfce685" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de6783a6-5be1-4a40-9146-cb160bfce685")) {                    Plotly.newPlot(                        "de6783a6-5be1-4a40-9146-cb160bfce685",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eyear=1952\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[556263527],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003eyear=1952\u003
# ...

# %%
# # YOUR CODE HERE
# import plotly.express as px

# ds = df.groupby("country")[["pop"]].sum().head(10)
# ds


# # fig = px.bar(df, 
# #              x='pop', 
# #              y='country',
# #              animation_frame='year',  # Specify the 'year' column for animation
# #              title='Population Growth by Continent Over the Years',
# # #              labels={'pop': 'Population'},
# #              category_orders={"country": df.groupby("country")["pop"].sum().head(10).sort_values(ascending=False).index},
# #              height=1000,  # Set the height of the plot
# #              color = 'continent'
# #             )

# # # Customize the layout (optional)
# # fig.update_layout(xaxis_title='Continent', yaxis_title='Population')
# # # fig.update_xaxes(type='category')

# # # Show the animated plot
# # fig.show()
# Out:
#                     pop
# country
# Afghanistan   189884585
# Albania        30962990
# Algeria       238504874
# Angola         87712681
# Argentina     343226879
# Australia     175791750
# Austria        90999581
# Bahrain         4486958
# Bangladesh   1089064744
# Belgium       116701424

# %%
import plotly.express as px
import pandas as pd

top_10 = df.groupby('year').apply(lambda x: x.nlargest(10, 'pop')).reset_index(drop=True)

fig = px.bar(top_10, 
             x='pop', 
             y='country',
             animation_frame='year',
             title='Top 10 Countries by Population',
             labels={'pop': 'Population'},
             height=600,
             color = 'country',
             orientation = 'h'
            )

fig.update_layout(xaxis_title='Country', yaxis_title='Population' ,title_x = 0.5 , title_y = .95)
fig.update_yaxes( categoryorder = 'total ascending')

fig.show()
# Out:
# <div>                            <div id="dc13c6fa-06e2-492e-bc26-84fd0189d372" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc13c6fa-06e2-492e-bc26-84fd0189d372")) {                    Plotly.newPlot(                        "dc13c6fa-06e2-492e-bc26-84fd0189d372",                        [{"alignmentgroup":"True","hovertemplate":"country=%{y}\u003cbr\u003eyear=1952\u003cbr\u003ePopulation=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[556263527],"xaxis":"x","y":["China"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{y}\u003cbr\u003eyear=1952\u003
# ...
